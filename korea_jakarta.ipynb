# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
url = "https://www.thejakartapost.com/search?q=korea"

# %%
main = "https://www.thejakartapost.com/"

# %%
req = requests.get(url)
rtxt = req.text
soup = BeautifulSoup(rtxt, 'lxml')

# %%
soup.find_all("div")
# Out:
# [<div class="bgNav"></div>, <div class="on-ie-underversion9">
#  <div class="col-xs-6 article-ie">
#  <h1>TheJakartaPost</h1>
#  <p>Please Update your browser</p>
#  <p>
#  Your browser is out of date, and may not be compatible with our website. A list of the most popular web browsers can be found below.<br/>
#  Just click on the icons to get to the download page.</p>
#  <a href="http://windows.microsoft.com/en-us/internet-explorer/download-ie" target="_blank">
#  <img alt="Jakarta Post" src="https://www.thejakartapost.com/skin/img/browser_msie.gif"/>
#  </a>
#  </div>
#  </div>, <div class="col-xs-6 article-ie">
#  <h1>TheJakartaPost</h1>
#  <p>Please Update your browser</p>
#  <p>
#  Your browser is out of date, and may not be compatible with our website. A list of the most popular web browsers can be found below.<br/>
#  Just click on the icons to get to the download page.</p>
#  <a href="http://windows.microsoft.com/en-us/internet-explorer/download-ie" target="_blank">
# ...

# %%
soup.select("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-thumbnail-inside > div > a")
# Out:
# []

# %%
soup.select("div.gs-title")
# Out:
# []

# %%
print(soup.find(id="___gcse_0"))
# Out:
# None

# %%
document.querySelector("#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-thumbnail-inside > div > a")
